# %%
import numpy as np
import pandas as pd
import sys, os

# %%
df = pd.read_csv(os.path.join(os.path.dirname(os.path.dirname(os.path.abspath('file'))), 'data', 'vac_com_1.csv'), sep = ',', encoding = 'latin-1')
df
# Out:
#               Unnamed: 0 Personas con al menos 1 dosis ?80 años       %  \
# 0              Andalucía                                433,728  100.0%
# 1                 Aragón                                101,253  100.0%
# 2              Asturias                                  88,951  100.0%
# 3               Baleares                                 51,483  100.0%
# 4               Canarias                                 93,033  100.0%
# 5              Cantabria                                 42,313  100.0%
# 6        Castilla y Leon                                229,322  100.0%
# 7   Castilla - La Mancha                                138,122  100.0%
# 8               Cataluña                                458,747  100.0%
# 9          C. Valenciana                                297,236  100.0%
# 10           Extremadura                                 78,256  100.0%
# 11               Galicia                                242,277  100.0%
# ...

# %%
df = df.iloc[:, 0:21]

df = df.rename(columns={'Unnamed: 0':'Comunidad',
                        'Personas con al menos 1 dosis ?80 años':'Mayores de 80 años',
                        'Personas con al menos 1 dosis 70-79 años':'70-79 años',
                        'Personas con al menos 1 dosis 60-69 años':'60-69 años',
                        'Personas con al menos 1 dosis 50-59 años':'50-59 años',
                        'Personas con al menos 1 dosis 40-49 años':'40-49 años',
                        'Personas con al menos 1 dosis 30-39 años':'30-39 años',
                        'Personas con al menos 1 dosis 20-29 años':'20-29 años',
                        'Personas con al menos 1 dosis 12-19 años':'12-19 años',
                        'Total Personas con al menos 1 dosis':'Total Personas',
                        'Total Población INE Población a Vacunar (1)':'Población a Vacunar',
                        '% Con al menos 1 dosis sobre Población a Vacunar INE':'% sobre Población a Vacunar',
                        '% Con al menos 1 dosis sobre Total Población INE':'% sobre Total Población'})
df
# Out:
#                Comunidad Mayores de 80 años       % 70-79 años     %.1  \
# 0              Andalucía            433,728  100.0%    653,445  100.0%
# 1                 Aragón            101,253  100.0%    119,261  100.0%
# 2              Asturias              88,951  100.0%    114,345  100.0%
# 3               Baleares             51,483  100.0%     79,236   98.4%
# 4               Canarias             93,033  100.0%    151,369   98.0%
# 5              Cantabria             42,313  100.0%     55,912  100.0%
# 6        Castilla y Leon            229,322  100.0%    250,482  100.0%
# 7   Castilla - La Mancha            138,122  100.0%    158,360   99.5%
# 8               Cataluña            458,747  100.0%    618,184   97.3%
# 9          C. Valenciana            297,236  100.0%    434,371   99.2%
# 10           Extremadura             78,256  100.0%     95,914  100.0%
# 11               Galicia            242,277  100.0%    291,287  100.0%
# ...

# %%
df.to_csv(os.path.join(os.path.dirname(os.path.dirname(os.path.abspath('file'))), 'data', 'vac_com_tableau1.csv'), sep=',')
