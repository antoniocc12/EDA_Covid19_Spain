# %%
import numpy as np
import pandas as pd
import sys, os

# %%
df = pd.read_csv(os.path.join(os.path.dirname(os.path.dirname(os.path.abspath('file'))), 'data', 'vac_com_2.csv'), sep = ',', encoding = 'latin-1')
df
# Out:
#               Unnamed: 0 Personas pauta completa ?80 años       %  \
# 0              Andalucía                          428,353  100.0%
# 1                 Aragón                           99,896  100.0%
# 2              Asturias                            88,159  100.0%
# 3               Baleares                           50,854  100.0%
# 4               Canarias                           91,898  100.0%
# 5              Cantabria                           41,847  100.0%
# 6        Castilla y Leon                          226,852  100.0%
# 7   Castilla - La Mancha                          136,189  100.0%
# 8               Cataluña                          452,937  100.0%
# 9          C. Valenciana                          293,157  100.0%
# 10           Extremadura                           77,382  100.0%
# 11               Galicia                          240,660  100.0%
# 12              La Rioja                           23,163  100.0%
# ...

# %%
df = df.iloc[:, 0:21]

df = df.rename(columns={'Personas pauta completa ?80 años':'Mayores de 80 años',
                        'Personas pauta completa 70-79 años':'70-79 años',
                        'Personas pauta completa 60-69 años	':'60-69 años',
                        'Personas pauta completa 50-59 años':'50-59 años',
                        'Personas pauta completa 40-49 años':'40-49 años',
                        'Personas pauta completa 30-39 años':'30-39 años',
                        'Personas pauta completa 20-29 años':'20-29 años',
                        'Personas pauta completa 12-19 años':'12-19 años',
                        'Total Personas pauta completa':'Total Personas',
                        'Población a Vacunar':'Población a Vacunar',
                        '% pauta completa sobre Población a Vacunar INE':'% sobre Población a Vacunar',
                        '% pauta completa sobre Total Población INE':'% sobre Total Población'})
df
# Out:
#               Unnamed: 0 Mayores de 80 años       % 70-79 años     %.1  \
# 0              Andalucía            428,353  100.0%    649,017   99.8%
# 1                 Aragón             99,896  100.0%    118,489   99.6%
# 2              Asturias              88,159  100.0%    113,911  100.0%
# 3               Baleares             50,854  100.0%     78,760   97.8%
# 4               Canarias             91,898  100.0%    150,170   97.2%
# 5              Cantabria             41,847  100.0%     55,692  100.0%
# 6        Castilla y Leon            226,852  100.0%    249,053  100.0%
# 7   Castilla - La Mancha            136,189  100.0%    157,126   98.8%
# 8               Cataluña            452,937  100.0%    614,051   96.7%
# 9          C. Valenciana            293,157  100.0%    431,674   98.6%
# 10           Extremadura             77,382  100.0%     95,401  100.0%
# 11               Galicia            240,660  100.0%    290,044  100.0%
# ...

# %%
df.to_csv(os.path.join(os.path.dirname(os.path.dirname(os.path.abspath('file'))), 'data', 'vac_com_tableau2.csv'), sep=',')
